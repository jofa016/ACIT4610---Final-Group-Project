# %% [markdown]
# # Multi-Constraint Knapsack with the Bees Algorithm (BA)

# %% [markdown]
# ## Table of Contents
# 1. [Install requirements](#section-install)
# 1. [Import libraries](#section-import)
# 1. [Dataset import - 6 instances](#section-dataset)
# 1. [Define parameters and instance](#section-parameters)
# 1. [The Bees Algorithm (BA)](#section-algorithm)
# 1. [Run experiment](#section-run)
# 1. [Experiment Results](#section-results)

# %% [markdown]
# ## <span id="section-install"></span>Install requirements

# %%
# install requirements from requirements.txt
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\welde\miniconda3\lib\site-packages (from -r ../requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy in c:\users\welde\miniconda3\lib\site-packages (from -r ../requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: matplotlib in c:\users\welde\miniconda3\lib\site-packages (from -r ../requirements.txt (line 3)) (3.9.2)
# Requirement already satisfied: seaborn in c:\users\welde\miniconda3\lib\site-packages (from -r ../requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\welde\miniconda3\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\welde\miniconda3\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\welde\miniconda3\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\welde\miniconda3\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\welde\miniconda3\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\welde\miniconda3\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\welde\miniconda3\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\welde\miniconda3\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\welde\miniconda3\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\welde\miniconda3\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (3.1.4)
# Requirement already satisfied: six>=1.5 in c:\users\welde\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 1)) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## <span id="section-import"></span>Import libraries

# %%
# Standard library
from pathlib import Path
import time

# Data handling
import numpy as np
import pandas as pd

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## <span id="section-dataset"></span>
# # Dataset import - 6 instances

# %% [markdown]
# The following files are pared for each instance for Beasley's OR-Library:
# <br>
# (https://people.brunel.ac.uk/~mastjjb/jeb/orlib/mknapinfo.html)
# <br>
# - **small 1:** mknapcb1.txt
# - **small 2:** mknapcb2.txt
# - **medium 1:** mknapcb4.txt
# - **medium 2:** mknapcb5.txt
# - **large 1:** mknapcb8.txt
# - **large 2:** mknapcb9.txt

# %%
# --- file paths for all instances ---
# small
MKNAPCB1_PATH = Path("./data/Knapsack/mknapcb1.txt")
MKNAPCB2_PATH = Path("./data/Knapsack/mknapcb2.txt")

# medium
MKNAPCB4_PATH = Path("./data/Knapsack/mknapcb4.txt")
MKNAPCB5_PATH = Path("./data/Knapsack/mknapcb5.txt")

# large
MKNAPCB8_PATH = Path("./data/Knapsack/mknapcb8.txt")
MKNAPCB9_PATH = Path("./data/Knapsack/mknapcb9.txt")

# %% [markdown]
# ### Internal helper functions

# %% [markdown]
# Read all numeric tokens:

# %%
def _read_numeric_tokens(path: Path) -> list[float]:
    """Read all numeric tokens from a file (ignore non-numeric)."""
    toks = []
    with open(path, "r") as f:
        for t in f.read().split():
            try:
                toks.append(float(t))
            except ValueError:          # ignore non-numeric artifacts
                pass
    return toks

# %% [markdown]
# Parser for all mknapcb OR-Library files. Reads text file describing multiple knapsack problem instances and convert each instance into a pandas `DataFrame`.

# %%
def parse_mknapcb_all(path: Path) -> list[pd.DataFrame]:
    """
    Parse all instances from a Beasley mknapcb*.txt file.

    Layout (OR-Library format):
        num_instances
        For each instance:
            n
            capacity m 0
            n profits
            m * n weights
            m capacities

    :param path: path to mknapcb*.txt file
    :return: list of DataFrames, with attrs: m, n, capacities (list[float]), name (str) -> one per instance
    """
    toks = _read_numeric_tokens(path)
    p = 0
    name_base = path.stem.upper()

    if p >= len(toks):
        raise ValueError(f"{path} contains no numeric tokens")

    num_instances = int(toks[p]); p += 1
    dfs: list[pd.DataFrame] = []

    # loop through each instance individually
    for inst in range(num_instances):

        # stop early if file is shorter than declared
        if p + 1 >= len(toks):
            break

        n = int(toks[p]); p += 1
        m = int(toks[p]); p += 1

        # some files have an optional zero right after (header artifact)
        if p < len(toks) and int(toks[p]) == 0:
            p += 1

        # profits
        prof = toks[p:p+n]; p += n
        if len(prof) < n:
            break

        # weights (m x n)
        weights = []
        for _ in range(m):
            row = toks[p:p+n]; p += n
            if len(row) < n:
                break
            weights.append(row)
        if len(weights) < m:
            break

        # capacities (m)
        caps = toks[p:p+m]; p += m
        if len(caps) < m:
            break

        df = pd.DataFrame({"Item": range(1, n + 1), "Profit": prof})
        for j in range(m):
            df[f"Weight_{j+1}"] = weights[j]

        df.attrs.update({
            "m": m,
            "n": n,
            "capacities": caps,
            "name": f"{name_base}#{inst+1}"
        })
        dfs.append(df)

    return dfs

# %% [markdown]
# A convenience wrapper for the more general `parse_mknapcb_all()`function. Select only the first instance from each file for the following experiment.

# %%
def parse_mknapcb_first(path: Path) -> pd.DataFrame:
    """
    Convenience: return only the first instance from a mknapcb file.

    :param path: path to mknapcb*.txt file
    """
    all_inst = parse_mknapcb_all(path)
    if not all_inst:
        raise ValueError(f"No instances parsed from {path}")
    return all_inst[0]

# %% [markdown]
# Produce tabular summaries of all instances parsed:

# %%
def tables(top_n: int = 10) -> dict[str, pd.DataFrame]:
    """
    Load the first instance from each selected mknapcb file,
    print a short summary, and return them in a dictionary.

    :param top_n: number of rows to print from each df  (default: 10)
    :return: datasets: dictionary mapping dataset names (str) -> pd.DataFrame
    """
    small_1 = parse_mknapcb_first(MKNAPCB1_PATH)
    small_2 = parse_mknapcb_first(MKNAPCB2_PATH)

    medium_1 = parse_mknapcb_first(MKNAPCB4_PATH)
    medium_2 = parse_mknapcb_first(MKNAPCB5_PATH)

    large_1 = parse_mknapcb_first(MKNAPCB8_PATH)
    large_2 = parse_mknapcb_first(MKNAPCB9_PATH)

    datasets = {
        "small_1": small_1,
        "small_2": small_2,
        "medium_1": medium_1,
        "medium_2": medium_2,
        "large_1": large_1,
        "large_2": large_2,
    }

    # print summaries + top N rows
    for label, df in datasets.items():
        print(f"\n=== {label} ===")
        print(f"{df.attrs['name']}: {df.attrs['n']} items, {df.attrs['m']} constraints")
        print("Capacities:", df.attrs["capacities"])
        print(df.head(top_n))

    return datasets


# save tables as ds
ds = tables(top_n=10)
ds["small_1"].describe()
# Out:
# === small_1 ===
# MKNAPCB1#1: 100 items, 5 constraints
# Capacities: [11927.0, 13727.0, 11551.0, 13056.0, 13460.0]
#    Item  Profit  Weight_1  Weight_2  Weight_3  Weight_4  Weight_5
# 0     1   504.0      42.0     509.0     806.0     404.0     475.0
# 1     2   803.0      41.0     883.0     361.0     197.0      36.0
# 2     3   667.0     523.0     229.0     199.0     817.0     287.0
# 3     4  1103.0     215.0     569.0     781.0    1000.0     577.0
# 4     5   834.0     819.0     706.0     596.0      44.0      45.0
# 5     6   585.0     551.0     639.0     669.0     307.0     700.0
# 6     7   811.0      69.0     114.0     957.0      39.0     803.0
# 7     8   856.0     193.0     727.0     358.0     659.0     654.0
# count  100.000000   100.00000  100.000000  100.000000  100.000000
# mean    50.500000   768.42000  477.070000  549.070000  462.030000
# std     29.011492   173.26235  293.753427  266.410644  292.447576
# min      1.000000   388.00000   41.000000   32.000000    4.000000
# 25%     25.750000   631.50000  217.250000  295.250000  197.250000
# 50%     50.500000   797.50000  471.500000  588.000000  409.000000
# 75%     75.250000   868.00000  732.000000  779.250000  744.750000
# max    100.000000  1169.00000  998.000000  967.000000  973.000000
#
#           Weight_4    Weight_5
# count   100.000000  100.000000
# mean    522.220000  538.400000
# std     297.945408  276.054416
# min      13.000000   25.000000
# 25%     277.250000  335.750000
# 50%     519.500000  579.500000
# 75%     783.000000  759.750000
# max    1000.000000  995.000000

# %% [markdown]
# ## Capacities for each instance

# %% [markdown]
# Plot bar chart of capacity limits for each constraint in a knapsack instance.
# <br>
# (Last code block in this section. Uncheck comment to view bar charts)

# %%
# --- helper function for plot_all_datasets ---
def plot_capacities(df, title_prefix=""):
    """
    Create bar chart for selected instances to display capacities of the knapsacks.

    :param df:              pandas DataFrame with instances
    :param title_prefix:    prefix for instance (instance identifier)
    """
    caps = np.array(df.attrs["capacities"], dtype=float)
    plt.figure()
    plt.bar(np.arange(len(caps)) + 1, caps, color="salmon")
    plt.title(f"{title_prefix}Constraint resource limits".strip())
    plt.xlabel("Constraint index")
    plt.ylabel("Capacity")

def plot_all_datasets(datasets, show=True, save_dir=None, bins=40):
    """
    Creates and displays plot profit histograms and capacities for all instances.

    :param: datasets: dict like {"medium_1": df, "medium_2": df, "large_1": df} - data with all instances
    :param: show:     call plt.show() at the end    (default: True)
    :param: save_dir: directory to save PNGs        (default: None)
    :param: bins:     histogram bins for profits    (default: 40)
    """
    save_dir = Path(save_dir) if save_dir else None
    if save_dir:
        save_dir.mkdir(parents=True, exist_ok=True)

    for label, df in datasets.items():
        prefix = f"{label} — "

        # profit histogram
        plt.figure()
        plt.hist(df["Profit"], bins=bins, color="skyblue", edgecolor="black")
        plt.title(f"{prefix}Distribution of item profits")
        plt.xlabel("Profit / Value")
        plt.ylabel("Frequency")
        if save_dir:
            plt.savefig(save_dir / f"{label}_profit_hist.png", bbox_inches="tight")

        # capacities bar plot
        plot_capacities(df, title_prefix=prefix)
        if save_dir:
            plt.savefig(save_dir / f"{label}_capacities.png", bbox_inches="tight")

    if show:
        plt.show()

# %%
# remove comment to plot capacities of each instance:
# plot_all_datasets(ds)

# %% [markdown]
# ## <span id="section-parameters"></span>
# # Define parameters and instance

# %%
# --- map instances to tables ---
instances = {
    "small_1": ds["small_1"],
    "small_2": ds["small_2"],
    "medium_1": ds["medium_1"],
    "medium_2": ds["medium_2"],
    "large_1": ds["large_1"],
    "large_2": ds["large_2"]
}

# pick instances to run
experiment_instances = {
    "small_1": instances["small_1"],
    "small_2": instances["small_2"],
    "medium_1": instances["medium_1"],
    "medium_2": instances["medium_2"],
    "large_1":  instances["large_1"],
    "large_2":  instances["large_2"]
}

# %%
#--- define 3 BA parameter sets ---
# balanced parameter set
params_balanced = {
    "n": 80,        # number of scout bees
    "nb": 20,       # number of best sites selected
    "ne": 5,        # number of elite sites
    "nre": 15,      # recruited bees around elite sites
    "nrb": 7,       # recruited bees around other best sites
    "ngh": 3,       # neighbourhood size (bits flipped)
    "stlim": 25,    # stagnation limit - stops iterations if no progress is made for x iterations
    "max_iter": 500
}

# explorative parameter set
params_exploration = {
    "n": 100,        # explore more of the search space
    "nb": 20,
    "ne": 5,
    "nre": 15,
    "nrb": 15,      # explore more around other best sites
    "ngh": 8,       # explore wider neighbourhoods
    "stlim": 25,
    "max_iter": 500
}

# exploitive parameter set
params_exploitation = {
    "n": 60,        # smaller population, more focused
    "nb": 20,
    "ne": 5,
    "nre": 25,      # more recruited bees = deeper local search
    "nrb": 7,
    "ngh": 3,
    "stlim": 25,
    "max_iter": 500
}

# --- combine into a single dictionary for experiments ---
parameter_sets = {
    "balanced": params_balanced,
    "exploration": params_exploration,
    "exploitation": params_exploitation
}


# --- known optimal values collected from mkcbres.txt from OR-Library -> for solution evaluation ---
known_optima = {
    "small_1": 24381,
    "small_2": 59312,
    "medium_1": 23064,
    "medium_2": 59187,
    "large_1": 56693,
    "large_2": 115868
}

# %% [markdown]
# ## <span id="section-algorithm"></span>
# # The Bees Algorithm (BA)

# %%
def bees_knapsack_mkp(values, W, b, n, nb, ne, nre, nrb, ngh, max_iter, stlim):
    """
    Optimization technique (Bees Algorithm) to solve the multi-constraint knapsack problem

    Repair strategy: removes lowest-value items until all capacity constraints are satisfied
    Stop criteria: terminates after `max_iter` iterations or when no improvement occurs over successive iterations

    :param: values :        array_like      -> resource usage matrix (m x n_items)
    :param: W :             array_like      -> capacity limits for each resource
    :param: b :             array_like      -> capacity limits for each resource
    :param: n :             int             -> number of scout bees (population size)
    :param: nb :            int             -> number of best sites selected for neighborhood search
    :param: ne :            int             -> number of elite sites
    :param: nre :           int             -> number of recruited bees per elite site
    :param: nrb :           int             -> number of recruited bees around each non-elite best site
    :param: ngh :           int             -> neighborhood size (bit flips per neighbor)
    :param: max_iter:       int             -> maximum number of iterations (generations)
    :param: stlim :         int             -> stagnation limit (stop criteria)

    :return: baseline_best: float           -> the best value in first population
    :return: best_value:    float           -> the best objective value found
    :return: best_solution: ndarray         -> binary vector of selected items
    :return: hist_best:     list of float   -> the best fitness per iteration
    :return: hist_avg:      list of float   -> average fitness per iteration
    :return: iter_of_best:  int             -> iteration when best solution found
    :return: runtime:       float           -> total execution time (seconds)
    """
    start = time.time()

    # convert to NumPy arrays for fast vectorized math
    values = np.asarray(values, float)
    W = np.asarray(W, float)
    b = np.asarray(b, float)

    # record shape of W ( m constraints, n items)
    m, n_items = W.shape

    norm_W = W / (b[:, None] + 1e-12)
    item_density = norm_W.sum(axis=0)
    profit_per_density = values / (item_density + 1e-12)


    # --- helper functions ---
    def is_feasible(x):
        """
        Feasible if the total weights per constraint don't exceed capacities.
        """
        return np.all(W @ x <= b + 1e-12)

    def repair(x):
        """
        Repair function -> greedy drop: remove items with the smallest profit_per_density until feasible.
        """
        x = x.copy()
        while True:
            totals = W @ x
            if np.all(totals <= b + 1e-12): break
            ones = np.where(x == 1)[0]
            if ones.size == 0: break
            worst = ones[np.argmin(profit_per_density[ones])]
            x[worst] = 0
        return x

    def fitness_of(x):
        """
        Evaluate fitness of solution.
        Fitness value = total profit.

        (Possibly repaired solution if it was infeasible)
        """
        if not is_feasible(x): x = repair(x)
        return float(values @ x), x


    # --- initialize population ---
    population = np.random.randint(0, 2, (n, n_items))
    fitness = np.zeros(n)
    for i in range(n):
        val, fx = fitness_of(population[i])
        population[i], fitness[i] = fx, val

    baseline_best = float(np.max(fitness))

    best_idx = int(np.argmax(fitness))
    best_value = float(fitness[best_idx])
    best_solution = population[best_idx].copy()
    iter_of_best = 0

    hist_best = [best_value]        # track global best
    hist_avg  = [float(np.mean(fitness))]

    # stagnation check (for stlim)
    no_improve_count = 0
    last_best = best_value


    # --- main BA loop ---
    for it in range(1, max_iter + 1):

        # sort population -> best to worst
        order = np.argsort(fitness)[::-1]
        population, fitness = population[order], fitness[order]

        new_population, new_fitness = [], []

        # neighbourhood search
        for i in range(nb):
            site = population[i].copy()
            recruits = nre if i < ne else nrb
            best_site_val = float(fitness[i])
            best_site_sol = site.copy()

            # explore neighbours
            for _ in range(recruits):
                neigh = site.copy()
                flips = np.random.randint(1, min(ngh, n_items) + 1)
                idx = np.random.choice(n_items, size=flips, replace=False)
                neigh[idx] = 1 - neigh[idx]
                val, neigh = fitness_of(neigh)
                if val > best_site_val:
                    best_site_val, best_site_sol = float(val), neigh.copy()

            # add best neighbour to new population
            new_population.append(best_site_sol)
            new_fitness.append(best_site_val)

        # add scout bees
        scouts = np.random.randint(0, 2, (n - nb, n_items))

        for s in scouts:
            val, s = fitness_of(s)
            new_population.append(s)
            new_fitness.append(float(val))

        population = np.array(new_population)
        fitness = np.array(new_fitness, float)

                # update global best
        improved = False
        current_best_idx = np.argmax(fitness)
        current_best_value = fitness[current_best_idx]

        if current_best_value > best_value + 1e-9:
            best_value = float(current_best_value)
            best_solution = population[current_best_idx].copy()
            iter_of_best = it
            no_improve_count = 0
            improved = True
        else:
            no_improve_count += 1

        # early stopping check
        if no_improve_count >= stlim:
            break

        hist_best.append(best_value)
        hist_avg.append(float(np.mean(fitness)))

    runtime = time.time() - start

    return baseline_best, best_value, best_solution, hist_best, hist_avg, iter_of_best, runtime

# %% [markdown]
# ## <span id="section-run"></span>
# # Run experiment

# %% [markdown]
# Run BA on all 6 instances for each of the 3 parameter sets. 10 runs for each instance to trach means and avoid evaluating on outliers.
# <br>
# ##### Columns in output table:
# - `Seed`: seed for run
# - `Instance`: instance for
# - `Items`: num of knapsack items available for the instance
# - `Constraints`: num of knapsack constraints for the instance
# - `Parameter_Set`: the parameter set used for the run
# - `Best_Value`: best value found for the run
# - `Optimal_Value`: known optimal value for the instance
# - `Deviation_%`: the deviation of best value from known optimal value
# - `Runtime_s`: runtime for the run in seconds
# - `Iterations`: number of iterations
# - `Iter_of_Best`: iteration where best value was found
# - `Used_Weight`: weights used
# - `Hist_Best`: historical best values from the run
# - `Hist_Avg`: historical averages from the run

# %%
def run_experiment_multi(instances, parameter_sets, seeds=range(10)):
    """
    Run Bees Algorithm across multiple MKP instances and parameter sets.
    Includes comparison with known optima when available.

    :param instances:       dict of problem instances (DataFrames)
    :param parameter_sets:  dict of parameter configurations
    :param seeds:           iterable of random seeds
    :return: pd.DataFrame:  all experiment results
    """
    rows = []

    # --- for each parameter (3) ---
    for param_label, params in parameter_sets.items():
        print(f"\nRunning parameter set: {param_label}")

        # --- for each instance (6) ---
        for inst_label, df in instances.items():
            print(f"Instance: {inst_label} ({df.attrs['n']} items, {df.attrs['m']} constraints)")

            values = df["Profit"].to_numpy(float)
            W = np.vstack([df[c].to_numpy(float) for c in df.columns if c.startswith("Weight_")])
            b = np.array(df.attrs["capacities"], float)

            # known optimum lookup
            opt = known_optima.get(inst_label, df.attrs.get("optimal_value", None))
            if opt is not None:
                print(f"Known optimum: {opt}")
            else:
                print(f"No known optimum available.")

            # --- for each seed (20) ---
            for seed in seeds:
                np.random.seed(seed)
                baseline, best, sol, h_best, h_avg, it_best, rt = bees_knapsack_mkp(values, W, b, **params)
                totals = (W @ sol).tolist()
                iterations = len(h_best) - 1

                # deviation from known optimum
                deviation = (
                    np.nan if (opt is None or not np.isfinite(opt) or opt == 0)
                    else 100 * (1 - best / opt)
                )

                # improvement (%) from baseline to best
                improvement = 100 * (1 - baseline / best)

                rows.append({
                    "Seed": seed,
                    "Instance": inst_label,
                    "Items": int(df.attrs["n"]),
                    "Constraints": int(df.attrs["m"]),
                    "Parameter_Set": param_label,
                    "Baseline_Best": float(baseline),
                    "Best_Value": float(best),
                    "Improvement": improvement,
                    "Optimal_Value": (None if opt is None else float(opt)),
                    "Deviation_%": deviation,
                    "Runtime_s": rt,
                    "Iterations": iterations,
                    "Iter_of_Best": it_best,
                    "Used_Weight": totals,
                    "Hist_Best": h_best,
                    "Hist_Avg": h_avg,
                })

                # print progress
                dev_str = "N/A" if np.isnan(deviation) else f"{deviation:.2f}%"
                improve_str = "N/A" if np.isnan(improvement) else f"{improvement:.2f}%"
                print(f"    Seed {seed:02d}: Baseline={baseline:.2f}, Best={best:.2f}, Improvement={improve_str}, Dev={dev_str}, Iterations={iterations}, Time={rt:.2f}s")

    print("\nAll experiments completed.")

    return pd.DataFrame(rows)

# %% [markdown]
# The following runs the complete experiment. Output is a dataframe (`multi_df`) that includes all results from each run.

# %%
# run experiment
multi_df = run_experiment_multi(experiment_instances, parameter_sets, seeds=range(10))
# Out:
# Running parameter set: balanced
# Instance: small_1 (100 items, 5 constraints)
# Known optimum: 24381
#     Seed 00: Baseline=21653.00, Best=23572.00, Improvement=8.14%, Dev=3.32%, Iterations=39, Time=1.52s
#     Seed 01: Baseline=21977.00, Best=23912.00, Improvement=8.09%, Dev=1.92%, Iterations=103, Time=4.07s
#     Seed 02: Baseline=21763.00, Best=23901.00, Improvement=8.95%, Dev=1.97%, Iterations=47, Time=0.93s
#     Seed 07: Baseline=19970.00, Best=22323.00, Improvement=10.54%, Dev=3.21%, Iterations=81, Time=1.65s
#     Seed 08: Baseline=20857.00, Best=22459.00, Improvement=7.13%, Dev=2.62%, Iterations=78, Time=1.63s
#     Seed 09: Baseline=20841.00, Best=22326.00, Improvement=6.65%, Dev=3.20%, Iterations=56, Time=1.18s
# Instance: medium_2 (250 items, 10 constraints)
# Known optimum: 59187
#     Seed 00: Baseline=52153.00, Best=56140.00, Improvement=7.10%, Dev=5.15%, Iterations=70, Time=3.19s
#     Seed 01: Baseline=53669.00, Best=56590.00, Improvement=5.16%, Dev=4.39%, Iterations=76, Time=3.29s
#     Seed 02: Baseline=52395.00, Best=57560.00, Improvement=8.97%, Dev=2.75%, Iterations=101, Time=4.36s
#     Seed 03: Baseline=53685.00, Best=56180.00, Improvement=4.44%, Dev=5.08%, Iterations=48, Time=2.10s
#     Seed 04: Baseline=53428.00, Best=57266.00, Improvement=6.70%, Dev=3.25%, Iterations=81, Time=3.49s
#     Seed 05: Baseline=52589.00, Best=56768.00, Improvement=7.36%, Dev=4.09%, Iterations=60, Time=2.63s
#     Seed 06: Baseline=52574.00, Best=57044.00, Improvement=7.84%, Dev=3.62%, Iterations=57, Time=2.49s
#     Seed 07: Baseline=53225.00, Best=56836.00, Improvement=6.35%, Dev=3.97%, Iterations=89, Time=3.86s
#     Seed 08: Baseline=53197.00, Best=57003.00, Improvement=6.68%, Dev=3.69%, Iterations=68, Time=2.98s
#     Seed 09: Baseline=52714.00, Best=57112.00, Improvement=7.70%, Dev=3.51%, Iterations=87, Time=3.82s
# Instance: large_1 (250 items, 30 constraints)
# Known optimum: 56693
#     Seed 00: Baseline=51651.00, Best=54434.00, Improvement=5.11%, Dev=3.98%, Iterations=87, Time=4.37s
#     Seed 01: Baseline=51589.00, Best=54811.00, Improvement=5.88%, Dev=3.32%, Iterations=52, Time=2.78s
#     Seed 02: Baseline=51955.00, Best=54418.00, Improvement=4.53%, Dev=4.01%, Iterations=53, Time=2.79s
#     Seed 03: Baseline=51769.00, Best=54080.00, Improvement=4.27%, Dev=4.61%, Iterations=44, Time=2.34s
#     Seed 04: Baseline=51749.00, Best=54614.00, Improvement=5.25%, Dev=3.67%, Iterations=91, Time=4.93s
#     Seed 05: Baseline=51248.00, Best=54347.00, Improvement=5.70%, Dev=4.14%, Iterations=66, Time=3.35s
#     Seed 06: Baseline=50984.00, Best=54914.00, Improvement=7.16%, Dev=3.14%, Iterations=75, Time=4.01s
#     Seed 07: Baseline=50662.00, Best=54799.00, Improvement=7.55%, Dev=3.34%, Iterations=62, Time=3.21s
#     Seed 08: Baseline=50972.00, Best=54921.00, Improvement=7.19%, Dev=3.13%, Iterations=105, Time=5.39s
#     Seed 09: Baseline=51388.00, Best=54191.00, Improvement=5.17%, Dev=4.41%, Iterations=55, Time=2.86s
# Instance: large_2 (500 items, 30 constraints)
# Known optimum: 115868
#     Seed 00: Baseline=105083.00, Best=112235.00, Improvement=6.37%, Dev=3.14%, Iterations=169, Time=21.72s
#     Seed 01: Baseline=104357.00, Best=111626.00, Improvement=6.51%, Dev=3.66%, Iterations=152, Time=17.82s
#     Seed 02: Baseline=105460.00, Best=112169.00, Improvement=5.98%, Dev=3.19%, Iterations=175, Time=20.97s
#     Seed 03: Baseline=105971.00, Best=111602.00, Improvement=5.05%, Dev=3.68%, Iterations=256, Time=31.10s
#     Seed 04: Baseline=105584.00, Best=111191.00, Improvement=5.04%, Dev=4.04%, Iterations=134, Time=15.66s
#     Seed 05: Baseline=104653.00, Best=111446.00, Improvement=6.10%, Dev=3.82%, Iterations=77, Time=9.01s
#     Seed 06: Baseline=105090.00, Best=111188.00, Improvement=5.48%, Dev=4.04%, Iterations=135, Time=15.77s
#     Seed 07: Baseline=106187.00, Best=110361.00, Improvement=3.78%, Dev=4.75%, Iterations=62, Time=7.38s
#     Seed 08: Baseline=104323.00, Best=112039.00, Improvement=6.89%, Dev=3.30%, Iterations=172, Time=20.23s
#     Seed 09: Baseline=105978.00, Best=110738.00, Improvement=4.30%, Dev=4.43%, Iterations=62, Time=7.24s
#
# Running parameter set: exploration
# Instance: small_1 (100 items, 5 constraints)
# Known optimum: 24381
#     Seed 00: Baseline=21653.00, Best=23642.00, Improvement=8.41%, Dev=3.03%, Iterations=49, Time=1.53s
#     Seed 01: Baseline=21977.00, Best=23984.00, Improvement=8.37%, Dev=1.63%, Iterations=57, Time=1.75s
#     Seed 02: Baseline=21763.00, Best=23922.00, Improvement=9.03%, Dev=1.88%, Iterations=65, Time=2.01s
#     Seed 03: Baseline=21563.00, Best=24175.00, Improvement=10.80%, Dev=0.84%, Iterations=74, Time=2.36s
#     Seed 04: Baseline=21986.00, Best=23714.00, Improvement=7.29%, Dev=2.74%, Iterations=41, Time=1.29s
#     Seed 05: Baseline=22189.00, Best=23575.00, Improvement=5.88%, Dev=3.31%, Iterations=43, Time=1.35s
#     Seed 06: Baseline=21773.00, Best=23669.00, Improvement=8.01%, Dev=2.92%, Iterations=40, Time=1.24s
#     Seed 07: Baseline=21870.00, Best=23811.00, Improvement=8.15%, Dev=2.34%, Iterations=48, Time=1.50s
#     Seed 08: Baseline=21666.00, Best=23867.00, Improvement=9.22%, Dev=2.11%, Iterations=62, Time=1.93s
#     Seed 09: Baseline=21880.00, Best=23767.00, Improvement=7.94%, Dev=2.52%, Iterations=82, Time=2.55s
# Instance: small_2 (250 items, 5 constraints)
# Known optimum: 59312
#     Seed 00: Baseline=53969.00, Best=57977.00, Improvement=6.91%, Dev=2.25%, Iterations=135, Time=8.12s
#     Seed 01: Baseline=53564.00, Best=57754.00, Improvement=7.25%, Dev=2.63%, Iterations=83, Time=5.07s
#     Seed 02: Baseline=53761.00, Best=57630.00, Improvement=6.71%, Dev=2.84%, Iterations=64, Time=3.92s
#     Seed 03: Baseline=53221.00, Best=57160.00, Improvement=6.89%, Dev=3.63%, Iterations=47, Time=2.87s
#     Seed 09: Baseline=52714.00, Best=56968.00, Improvement=7.47%, Dev=3.75%, Iterations=60, Time=3.94s
# Instance: large_1 (250 items, 30 constraints)
# Known optimum: 56693
#     Seed 00: Baseline=51812.00, Best=54659.00, Improvement=5.21%, Dev=3.59%, Iterations=41, Time=3.12s
#     Seed 01: Baseline=51589.00, Best=55123.00, Improvement=6.41%, Dev=2.77%, Iterations=97, Time=7.25s
#     Seed 02: Baseline=51955.00, Best=54255.00, Improvement=4.24%, Dev=4.30%, Iterations=49, Time=3.72s
#     Seed 03: Baseline=51769.00, Best=55124.00, Improvement=6.09%, Dev=2.77%, Iterations=51, Time=3.87s
#     Seed 04: Baseline=51749.00, Best=54882.00, Improvement=5.71%, Dev=3.19%, Iterations=144, Time=11.02s
#     Seed 05: Baseline=51248.00, Best=55057.00, Improvement=6.92%, Dev=2.89%, Iterations=69, Time=5.22s
#     Seed 06: Baseline=50984.00, Best=55164.00, Improvement=7.58%, Dev=2.70%, Iterations=118, Time=9.04s
#     Seed 07: Baseline=51034.00, Best=55153.00, Improvement=7.47%, Dev=2.72%, Iterations=118, Time=9.06s
#     Seed 08: Baseline=50972.00, Best=54725.00, Improvement=6.86%, Dev=3.47%, Iterations=58, Time=4.43s
#     Seed 09: Baseline=51388.00, Best=54782.00, Improvement=6.20%, Dev=3.37%, Iterations=87, Time=6.59s
# Instance: large_2 (500 items, 30 constraints)
# Known optimum: 115868
#     Seed 00: Baseline=107116.00, Best=111417.00, Improvement=3.86%, Dev=3.84%, Iterations=102, Time=16.79s
#     Seed 01: Baseline=104357.00, Best=112176.00, Improvement=6.97%, Dev=3.19%, Iterations=143, Time=23.34s
#     Seed 02: Baseline=105460.00, Best=112927.00, Improvement=6.61%, Dev=2.54%, Iterations=343, Time=40.13s
#     Seed 03: Baseline=105971.00, Best=112305.00, Improvement=5.64%, Dev=3.08%, Iterations=139, Time=14.23s
#     Seed 04: Baseline=105584.00, Best=110703.00, Improvement=4.62%, Dev=4.46%, Iterations=50, Time=5.40s
#     Seed 05: Baseline=106376.00, Best=111823.00, Improvement=4.87%, Dev=3.49%, Iterations=128, Time=13.11s
#     Seed 06: Baseline=105090.00, Best=111603.00, Improvement=5.84%, Dev=3.68%, Iterations=153, Time=15.90s
#     Seed 07: Baseline=106187.00, Best=112145.00, Improvement=5.31%, Dev=3.21%, Iterations=162, Time=16.48s
#     Seed 08: Baseline=104605.00, Best=112116.00, Improvement=6.70%, Dev=3.24%, Iterations=206, Time=20.95s
#     Seed 09: Baseline=105978.00, Best=111761.00, Improvement=5.17%, Dev=3.54%, Iterations=80, Time=8.22s
#
# Running parameter set: exploitation
# Instance: small_1 (100 items, 5 constraints)
# Known optimum: 24381
#     Seed 00: Baseline=21653.00, Best=23844.00, Improvement=9.19%, Dev=2.20%, Iterations=93, Time=0.99s
#     Seed 01: Baseline=21977.00, Best=23829.00, Improvement=7.77%, Dev=2.26%, Iterations=52, Time=0.60s
#     Seed 02: Baseline=21763.00, Best=23507.00, Improvement=7.42%, Dev=3.58%, Iterations=31, Time=0.35s
#     Seed 03: Baseline=21563.00, Best=23533.00, Improvement=8.37%, Dev=3.48%, Iterations=35, Time=0.38s
#     Seed 04: Baseline=21986.00, Best=23903.00, Improvement=8.02%, Dev=1.96%, Iterations=71, Time=0.73s
#     Seed 05: Baseline=22189.00, Best=23473.00, Improvement=5.47%, Dev=3.72%, Iterations=101, Time=1.04s
#     Seed 06: Baseline=21773.00, Best=23581.00, Improvement=7.67%, Dev=3.28%, Iterations=32, Time=0.34s
#     Seed 07: Baseline=21870.00, Best=23651.00, Improvement=7.53%, Dev=2.99%, Iterations=70, Time=0.73s
#     Seed 08: Baseline=21666.00, Best=24048.00, Improvement=9.91%, Dev=1.37%, Iterations=104, Time=1.07s
#     Seed 09: Baseline=21880.00, Best=23666.00, Improvement=7.55%, Dev=2.93%, Iterations=72, Time=0.74s
# Instance: small_2 (250 items, 5 constraints)
# Known optimum: 59312
#     Seed 00: Baseline=53969.00, Best=56958.00, Improvement=5.25%, Dev=3.97%, Iterations=63, Time=1.25s
#     Seed 01: Baseline=53564.00, Best=57118.00, Improvement=6.22%, Dev=3.70%, Iterations=55, Time=1.09s
#     Seed 02: Baseline=53761.00, Best=57060.00, Improvement=5.78%, Dev=3.80%, Iterations=54, Time=1.07s
#     Seed 03: Baseline=53085.00, Best=57252.00, Improvement=7.28%, Dev=3.47%, Iterations=83, Time=1.63s
#     Seed 04: Baseline=53638.00, Best=57412.00, Improvement=6.57%, Dev=3.20%, Iterations=95, Time=1.86s
#     Seed 05: Baseline=53230.00, Best=57636.00, Improvement=7.64%, Dev=2.83%, Iterations=121, Time=2.34s
#     Seed 06: Baseline=53283.00, Best=58099.00, Improvement=8.29%, Dev=2.05%, Iterations=114, Time=2.20s
#     Seed 07: Baseline=53745.00, Best=57160.00, Improvement=5.97%, Dev=3.63%, Iterations=83, Time=1.63s
#     Seed 08: Baseline=53643.00, Best=57802.00, Improvement=7.20%, Dev=2.55%, Iterations=109, Time=2.11s
#     Seed 09: Baseline=53392.00, Best=57069.00, Improvement=6.44%, Dev=3.78%, Iterations=58, Time=1.15s
# Instance: medium_1 (100 items, 10 constraints)
# Known optimum: 23064
#     Seed 00: Baseline=20993.00, Best=22230.00, Improvement=5.56%, Dev=3.62%, Iterations=49, Time=0.54s
#     Seed 01: Baseline=21007.00, Best=22505.00, Improvement=6.66%, Dev=2.42%, Iterations=63, Time=0.68s
#     Seed 02: Baseline=21151.00, Best=22604.00, Improvement=6.43%, Dev=1.99%, Iterations=65, Time=0.71s
#     Seed 03: Baseline=21217.00, Best=22272.00, Improvement=4.74%, Dev=3.43%, Iterations=53, Time=0.58s
#     Seed 04: Baseline=20523.00, Best=22553.00, Improvement=9.00%, Dev=2.22%, Iterations=47, Time=0.52s
#     Seed 05: Baseline=20367.00, Best=22329.00, Improvement=8.79%, Dev=3.19%, Iterations=36, Time=0.40s
#     Seed 06: Baseline=21419.00, Best=22166.00, Improvement=3.37%, Dev=3.89%, Iterations=47, Time=0.51s
#     Seed 07: Baseline=19970.00, Best=22387.00, Improvement=10.80%, Dev=2.94%, Iterations=87, Time=0.94s
#     Seed 08: Baseline=20857.00, Best=22357.00, Improvement=6.71%, Dev=3.07%, Iterations=85, Time=0.91s
#     Seed 09: Baseline=20584.00, Best=22400.00, Improvement=8.11%, Dev=2.88%, Iterations=58, Time=0.63s
# Instance: medium_2 (250 items, 10 constraints)
# Known optimum: 59187
#     Seed 00: Baseline=52153.00, Best=57002.00, Improvement=8.51%, Dev=3.69%, Iterations=69, Time=1.42s
#     Seed 01: Baseline=53669.00, Best=56998.00, Improvement=5.84%, Dev=3.70%, Iterations=86, Time=1.78s
#     Seed 02: Baseline=52395.00, Best=57106.00, Improvement=8.25%, Dev=3.52%, Iterations=56, Time=1.16s
#     Seed 03: Baseline=53685.00, Best=57097.00, Improvement=5.98%, Dev=3.53%, Iterations=103, Time=2.11s
#     Seed 04: Baseline=52856.00, Best=57189.00, Improvement=7.58%, Dev=3.38%, Iterations=84, Time=1.74s
#     Seed 05: Baseline=52589.00, Best=57256.00, Improvement=8.15%, Dev=3.26%, Iterations=53, Time=1.11s
#     Seed 06: Baseline=52371.00, Best=57588.00, Improvement=9.06%, Dev=2.70%, Iterations=147, Time=2.98s
#     Seed 07: Baseline=53225.00, Best=57329.00, Improvement=7.16%, Dev=3.14%, Iterations=69, Time=1.43s
#     Seed 08: Baseline=53197.00, Best=57779.00, Improvement=7.93%, Dev=2.38%, Iterations=103, Time=2.12s
#     Seed 09: Baseline=52714.00, Best=57568.00, Improvement=8.43%, Dev=2.74%, Iterations=114, Time=2.34s
# Instance: large_1 (250 items, 30 constraints)
# Known optimum: 56693
#     Seed 00: Baseline=51651.00, Best=54632.00, Improvement=5.46%, Dev=3.64%, Iterations=62, Time=1.49s
#     Seed 01: Baseline=51589.00, Best=54231.00, Improvement=4.87%, Dev=4.34%, Iterations=66, Time=1.60s
#     Seed 02: Baseline=51955.00, Best=54907.00, Improvement=5.38%, Dev=3.15%, Iterations=118, Time=2.77s
#     Seed 03: Baseline=51769.00, Best=54574.00, Improvement=5.14%, Dev=3.74%, Iterations=67, Time=1.63s
#     Seed 04: Baseline=51749.00, Best=54843.00, Improvement=5.64%, Dev=3.26%, Iterations=102, Time=2.47s
#     Seed 05: Baseline=51248.00, Best=54489.00, Improvement=5.95%, Dev=3.89%, Iterations=118, Time=2.80s
#     Seed 06: Baseline=50984.00, Best=55120.00, Improvement=7.50%, Dev=2.77%, Iterations=83, Time=1.98s
#     Seed 07: Baseline=50478.00, Best=55209.00, Improvement=8.57%, Dev=2.62%, Iterations=127, Time=3.01s
#     Seed 08: Baseline=50972.00, Best=54262.00, Improvement=6.06%, Dev=4.29%, Iterations=48, Time=1.17s
#     Seed 09: Baseline=51388.00, Best=55258.00, Improvement=7.00%, Dev=2.53%, Iterations=90, Time=2.17s
# Instance: large_2 (500 items, 30 constraints)
# Known optimum: 115868
#     Seed 00: Baseline=105083.00, Best=111260.00, Improvement=5.55%, Dev=3.98%, Iterations=82, Time=4.32s
#     Seed 01: Baseline=104357.00, Best=111682.00, Improvement=6.56%, Dev=3.61%, Iterations=157, Time=8.11s
#     Seed 02: Baseline=105460.00, Best=112137.00, Improvement=5.95%, Dev=3.22%, Iterations=138, Time=7.17s
#     Seed 03: Baseline=104882.00, Best=111011.00, Improvement=5.52%, Dev=4.19%, Iterations=158, Time=8.16s
#     Seed 04: Baseline=105584.00, Best=111467.00, Improvement=5.28%, Dev=3.80%, Iterations=46, Time=2.46s
#     Seed 05: Baseline=104093.00, Best=112304.00, Improvement=7.31%, Dev=3.08%, Iterations=175, Time=9.06s
#     Seed 06: Baseline=105025.00, Best=111013.00, Improvement=5.39%, Dev=4.19%, Iterations=97, Time=5.08s
#     Seed 07: Baseline=106187.00, Best=110885.00, Improvement=4.24%, Dev=4.30%, Iterations=60, Time=3.17s
#     Seed 08: Baseline=104323.00, Best=111927.00, Improvement=6.79%, Dev=3.40%, Iterations=99, Time=5.17s
#     Seed 09: Baseline=105510.00, Best=111150.00, Improvement=5.07%, Dev=4.07%, Iterations=125, Time=6.48s
#
# All experiments completed.

# %% [markdown]
# ## <span id="section-results"></span>
# # Experiment Results

# %% [markdown]
# ## Combining experiment results into one aggregated table (mean/std between seeds)

# %%
def summarize_experiment(multi_df):
    """
    Aggregate experiment results (multi_df) into one row per Instance × Parameter_Set.

    Computes:
    - baseline_mean = mean baseline best
    - best_mean = mean best value
    - runtime_mean = mean runtime
    - deviation_mean = mean deviation from optimum value
    - deviation_min = minimum deviation from optimum value
    - deviation_max = maximum deviation from optimum value
    - runtime_min = minimum runtime
    - runtime_max = maximum runtime
    - iter_mean = mean number of iterations
    - iter_best_mean = mean number of iterations when best value was found
    - hist_best_mean = elementwise mean (list)
    - hist_avg_mean = elementwise mean (list)

    :param multi_df: pd.DataFrame of results of all 20 seeds of experiment
    :return: pd.DataFrame of aggregated results of experiment
    """

    def mean_list(list_series):
        """Compute elementwise mean of lists (histories) across seeds."""
        valid = [np.asarray(x, dtype=float) for x in list_series if isinstance(x, (list, np.ndarray))]
        if not valid:
            return []
        min_len = min(len(lst) for lst in valid)
        arr = np.vstack([lst[:min_len] for lst in valid])
        return arr.mean(axis=0).tolist()

    results = []

    grouped = multi_df.groupby(["Instance", "Parameter_Set"], dropna=False)

    for (inst_label, param_label), group in grouped:
        n_items = group["Items"].mean()
        n_constraints = group["Constraints"].mean()
        baseline_mean = group["Baseline_Best"].mean()
        best_mean = group["Best_Value"].mean()
        best_min = group["Best_Value"].min()
        best_max = group["Best_Value"].max()
        runtime_mean = group["Runtime_s"].mean()
        runtime_min = group["Runtime_s"].min()
        runtime_max = group["Runtime_s"].max()
        deviation_mean = group["Deviation_%"].mean()
        deviation_min = group["Deviation_%"].min()
        deviation_max = group["Deviation_%"].max()
        iter_mean = group["Iterations"].mean()
        iter_best_mean = group["Iter_of_Best"].mean()

        # histories (elementwise mean)
        hist_best_mean = mean_list(group["Hist_Best"])
        hist_avg_mean = mean_list(group["Hist_Avg"])

        # list of weights
        used_weight_mean = mean_list(group["Used_Weight"])

        # Improvement based on aggregated means
        improvement = 100 * (best_mean - baseline_mean) / baseline_mean

        results.append({
            "Instance": inst_label,
            "Parameter_Set": param_label,
            "Items": int(n_items),
            "Constraints": int(n_constraints),
            "Baseline_Best": round(baseline_mean, 2),
            "Best_Value": round(best_mean, 2),
            "Best_Value_min": round(best_min, 2),
            "Best_Value_max": round(best_max, 2),
            "Improvement": round(improvement, 2),
            "Deviation_%": round(deviation_mean, 2),
            "Deviation_min": round(deviation_min, 2),
            "Deviation_max": round(deviation_max, 2),
            "Runtime_s": round(runtime_mean, 2),
            "Runtime_min": round(runtime_min, 2),
            "Runtime_max": round(runtime_max, 2),
            "Iterations": round(iter_mean, 2),
            "Iter_of_Best": round(iter_best_mean, 2),
            "Used_Weight_avg": used_weight_mean,
            "Hist_Best": hist_best_mean,
            "Hist_Avg": hist_avg_mean,
        })

    results_df = pd.DataFrame(results)
    return results_df

# %%
# aggregate multi_df to -> results_df
results_df = summarize_experiment(multi_df)
results_df.head(6)
# Out:
#   Instance Parameter_Set  Items  Constraints  Baseline_Best  Best_Value  \
# 0  large_1      balanced    250           30        51396.7     54552.9
# 1  large_1  exploitation    250           30        51378.3     54752.5
# 2  large_1   exploration    250           30        51450.0     54892.4
# 3  large_2      balanced    500           30       105268.6    111459.5
# 4  large_2  exploitation    500           30       105050.4    111483.6
# 5  large_2   exploration    500           30       105672.4    111897.6
#
#    Best_Value_min  Best_Value_max  Improvement  Deviation_%  Deviation_min  \
# 0         54080.0         54921.0         6.14         3.77           3.13
# 1         54231.0         55258.0         6.57         3.42           2.53
# 2         54255.0         55164.0         6.69         3.18           2.70
# 3        110361.0        112235.0         5.88         3.80           3.14
# 4        110885.0        112304.0         6.12         3.78           3.08
# 5        110703.0        112927.0         5.89         3.43           2.54
#
#    Deviation_max  Runtime_s  Runtime_min  Runtime_max  Iterations  \
# 0           4.61       3.60         2.34         5.39        69.0
# 1           4.34       2.11         1.17         3.01        88.1
# 2           4.30       6.33         3.12        11.02        83.2
# 3           4.75      16.69         7.24        31.10       139.4
# 4           4.30       5.92         2.46         9.06       113.7
# 5           4.46      17.45         5.40        40.13       150.6
#
#    Iter_of_Best                                    Used_Weight_avg  \
# 0          45.0  [29542.4, 30231.3, 30919.6, 29926.7, 28721.9, ...
# 1          64.1  [30673.6, 30340.6, 30868.9, 30409.6, 29245.9, ...
# 2          59.2  [30634.0, 29919.5, 30744.3, 30442.9, 28738.9, ...
# 3         115.4  [62964.1, 57083.1, 60310.8, 60175.1, 59968.4, ...
# 4          89.7  [62334.7, 56705.9, 60149.4, 60939.9, 59442.9, ...
# 5         126.6  [62517.0, 56934.7, 60258.7, 60731.3, 59939.0, ...
#
#                                            Hist_Best  \
# 0  [51396.7, 51932.7, 52186.2, 52615.3, 52806.2, ...
# 1  [51378.3, 52000.4, 52320.7, 52524.9, 52843.1, ...
# 2  [51450.0, 52214.9, 52630.2, 52958.5, 53186.3, ...
# 3  [105268.6, 106038.1, 106510.1, 106774.1, 10691...
# 4  [105050.4, 105936.9, 106324.6, 106681.6, 10693...
# 5  [105672.4, 106316.0, 106768.7, 107163.3, 10732...
#
#                                             Hist_Avg
# 0  [48304.13, 48755.92, 48940.441249999996, 49065...
# 1  [48340.92833333334, 49014.11166666666, 49213.8...
# 2  [48281.96399999999, 48836.262, 48873.194, 4895...
# 3  [100717.27249999999, 101556.95000000001, 10169...
# 4  [100742.90333333332, 101699.575, 101912.97, 10...
# 5  [100758.98199999999, 101487.48400000001, 10162...

# %% [markdown]
# ### <span id="section-results-tables"></span>5.2 Experiment Results Tables

# %% [markdown]
# The table shows the average between all 10 seeds on each instance and parameter set to avoid the risk on analysing on outliers or coincidences in a run.

# %%
def build_project_table(results_df, style=True):
    """
    Build a results table for experiment results.
    Output columns: instance, n, W, baseline value, best value, weight used, improvement %.
    """

    # select columns
    table = results_df[[
        "Instance",
        "Parameter_Set",
        "Items",
        "Constraints",
        "Baseline_Best",
        "Best_Value",
        "Used_Weight_avg",
        "Improvement",
        "Deviation_%",
        "Runtime_s"
    ]].copy()

    # rename columns for presentation
    table.rename(columns={
        "Items": "n",
        "Constraints": "W",
        "Baseline_Best": "Baseline Value",
        "Best_Value": "Best Value",
        "Used_Weight_avg": "Weight Used",
        "Improvement": "Improvement (%)",
        "Deviation_%": "Deviation (%)",
        "Runtime_s": "Runtime (s)"
    }, inplace=True)

    # format numeric values
    for col in ["Best Value", "Baseline Value", "Improvement (%)", "Runtime (s)"]:
        table[col] = table[col].apply(lambda x: f"{x:,.2f}")

    # format weights
    def format_weights(w):
        if isinstance(w, (list, tuple, np.ndarray)):
            # Limit to 5 values per row for readability
            return "[" + ", ".join(f"{x:.1f}" for x in w) + "]"
        return str(w)
    table["Weight Used"] = table["Weight Used"].apply(format_weights)

    # sort by instance size
    table.sort_values(by=["W", "n"], inplace=True, ignore_index=True)

    # style table for presentation
    if style:
        styled = (
            table.style
            .hide(axis="index")
            .set_caption("Summary of Bees Algorithm Results for MKP Instances")
            .set_table_styles([
                {"selector": "",
                 "props": [("transform", "scale(0.7)"),
                           ("transform-origin", "top left")]},
                {"selector": "caption",
                 "props": [("font-size", "16px"),
                           ("text-align", "left"),
                           ("font-weight", "bold"),
                           ("color", "#2C3E50"),
                           ("margin-bottom", "10px")]},
                {"selector": "th",
                 "props": [("background-color", "#1F618D"),
                           ("color", "white"),
                           ("font-weight", "bold"),
                           ("text-align", "center"),
                           ("padding", "6px 10px")]},
                {"selector": "td",
                 "props": [("text-align", "center"),
                           ("padding", "5px 10px"),
                           ("border", "1px solid #DDDDDD")]}
            ])
            .format(precision=2)
        )
        return styled


    return table

summary_table = build_project_table(results_df)
summary_table
# Out:
# <style type="text/css">
# #T_54883  {
#   transform: scale(0.7);
#   transform-origin: top left;
# }
# #T_54883 caption {
#   font-size: 16px;
#   text-align: left;
#   font-weight: bold;
#   color: #2C3E50;
#   margin-bottom: 10px;
# }
# #T_54883 th {
#   background-color: #1F618D;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 6px 10px;
# }
# #T_54883 td {
#   text-align: center;
#   padding: 5px 10px;
#   border: 1px solid #DDDDDD;
# }
# </style>
# <table id="T_54883">
#   <caption>Summary of Bees Algorithm Results for MKP Instances</caption>
#   <thead>
#     <tr>
#       <th id="T_54883_level0_col0" class="col_heading level0 col0" >Instance</th>
#       <th id="T_54883_level0_col1" class="col_heading level0 col1" >Parameter_Set</th>
#       <th id="T_54883_level0_col2" class="col_heading level0 col2" >n</th>
#       <th id="T_54883_level0_col3" class="col_heading level0 col3" >W</th>
#       <th id="T_54883_level0_col4" class="col_heading level0 col4" >Baseline Value</th>
#       <th id="T_54883_level0_col5" class="col_heading level0 col5" >Best Value</th>
#       <th id="T_54883_level0_col6" class="col_heading level0 col6" >Weight Used</th>
#       <th id="T_54883_level0_col7" class="col_heading level0 col7" >Improvement (%)</th>
#       <th id="T_54883_level0_col8" class="col_heading level0 col8" >Deviation (%)</th>
#       <th id="T_54883_level0_col9" class="col_heading level0 col9" >Runtime (s)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_54883_row0_col0" class="data row0 col0" >small_1</td>
#       <td id="T_54883_row0_col1" class="data row0 col1" >balanced</td>
#       <td id="T_54883_row0_col2" class="data row0 col2" >100</td>
#       <td id="T_54883_row0_col3" class="data row0 col3" >5</td>
#       <td id="T_54883_row0_col4" class="data row0 col4" >21,832.00</td>
#       <td id="T_54883_row0_col5" class="data row0 col5" >23,753.30</td>
#       <td id="T_54883_row0_col6" class="data row0 col6" >[11781.1, 13493.2, 11365.2, 12962.4, 12343.1]</td>
#       <td id="T_54883_row0_col7" class="data row0 col7" >8.80</td>
#       <td id="T_54883_row0_col8" class="data row0 col8" >2.57</td>
#       <td id="T_54883_row0_col9" class="data row0 col9" >1.44</td>
#     </tr>
#     <tr>
#       <td id="T_54883_row1_col0" class="data row1 col0" >small_1</td>
#       <td id="T_54883_row1_col1" class="data row1 col1" >exploitation</td>
#       <td id="T_54883_row1_col2" class="data row1 col2" >100</td>
#       <td id="T_54883_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_54883_row1_col4" class="data row1 col4" >21,832.00</td>
#       <td id="T_54883_row1_col5" class="data row1 col5" >23,703.50</td>
#       <td id="T_54883_row1_col6" class="data row1 col6" >[11414.5, 13675.1, 11426.2, 12938.5, 12805.9]</td>
#       <td id="T_54883_row1_col7" class="data row1 col7" >8.57</td>
#       <td id="T_54883_row1_col8" class="data row1 col8" >2.78</td>
#       <td id="T_54883_row1_col9" class="data row1 col9" >0.70</td>
#     </tr>
#     <tr>
#       <td id="T_54883_row2_col0" class="data row2 col0" >small_1</td>
#       <td id="T_54883_row2_col1" class="data row2 col1" >exploration</td>
#       <td id="T_54883_row2_col2" class="data row2 col2" >100</td>
#       <td id="T_54883_row2_col3" class="data row2 col3" >5</td>
#       <td id="T_54883_row2_col4" class="data row2 col4" >21,832.00</td>
#       <td id="T_54883_row2_col5" class="data row2 col5" >23,812.60</td>
#       <td id="T_54883_row2_col6" class="data row2 col6" >[11563.2, 13624.0, 11372.7, 12953.7, 12827.4]</td>
#       <td id="T_54883_row2_col7" class="data row2 col7" >9.07</td>
#       <td id="T_54883_row2_col8" class="data row2 col8" >2.33</td>
#       <td id="T_54883_row2_col9" class="data row2 col9" >1.75</td>
#     </tr>
#     <tr>
#       <td id="T_54883_
td>
#     </tr>
#     <tr>
#       <td id="T_54883_row7_col0" class="data row7 col0" >medium_1</td>
#       <td id="T_54883_row7_col1" class="data row7 col1" >exploitation</td>
#       <td id="T_54883_row7_col2" class="data row7 col2" >100</td>
#       <td id="T_54883_row7_col3" class="data row7 col3" >10</td>
#       <td id="T_54883_row7_col4" class="data row7 col4" >20,808.80</td>
#       <td id="T_54883_row7_col5" class="data row7 col5" >22,380.30</td>
#       <td id="T_54883_row7_col6" class="data row7 col6" >[13395.9, 11896.1, 11583.7, 13684.2, 12022.9, 11826.0, 11600.7, 12152.1, 12004.5, 9761.8]</td>
#       <td id="T_54883_row7_col7" class="data row7 col7" >7.55</td>
#       <td id="T_54883_row7_col8" class="data row7 col8" >2.96</td>
#       <td id="T_54883_row7_col9" class="data row7 col9" >0.64</td>
#     </tr>
#     <tr>
#       <td id="T_54883_row8_col0" class="data row8 col0" >medium_1</td>
#       <td id="T_54883_row8_col1" class="data row8 col1" >exploration</td>
#       <td id="T_54883_row8_col2" class="data row8 col2" >100</td>
#       <td id="T_54883_row8_col3" class="data row8 col3" >10</td>
#       <td id="T_54883_row8_col4" class="data row8 col4" >21,023.30</td>
#       <td id="T_54883_row8_col5" class="data row8 col5" >22,536.80</td>
#       <td id="T_54883_row8_col6" class="data row8 col6" >[13380.5, 11916.4, 11764.3, 13640.8, 11970

# %% [markdown]
# Style definitions for visualisations:

# %%
# --- Style library for visualisation ---

# instance color mapping
instance_colors = {
    "small_1": "#b3edad",   # light green
    "small_2": "#3ECC1B",   # green
    "medium_1": "#a0c9f0",  # light blue
    "medium_2": "#2E7CF4",  # blue
    "large_1": "#ee7c6c",   # pink
    "large_2": "#EA3131",   # red
}

# parameter set color mapping
param_colors = {
    "balanced": "#E8A317",      # mustard yellow
    "exploration": "#5C4B3C",   # brown
    "exploitation": "#4BA3C3",
}

# marker shapes for param sets
markers = {
    "balanced": "o",
    "exploration": "*",
    "exploitation": "^"
}

# ensure order of param sets in visualisations
param_order = ["balanced", "exploration", "exploitation"]

# %% [markdown]
# #### <span id="section-solution-quality"></span>Solution Quality

# %%
# keep ascending order of instances
order = ['small_1', 'small_2', 'medium_1', 'medium_2', 'large_1', 'large_2']

# solution quality table
solution_Q_table = (
    results_df
    .pivot_table(index='Instance', columns='Parameter_Set', values=['Deviation_%', 'Deviation_min', 'Deviation_max'])
    .rename_axis(columns=['Metric', 'Param set'])
    .rename(columns={'Deviation_%': 'Avg.', 'Deviation_min': 'Best', 'Deviation_max': 'Worst'})
    .reorder_levels(['Param set', 'Metric'], axis=1)
    .sort_index(axis=1, level=0)
    .reindex(order)
    .reindex(columns=param_order, level='Param set')
)

# stylize table
def style_table(df, title, cmap='YlGnBu', precision=2, clip_quantiles=(0.01, 0.99)):
    styled = df.style.format(f"{{:.{precision}f}}")

    # Compute global vmin/vmax, but clip outliers for balance
    vmin = df.quantile(clip_quantiles[0]).min().min()
    vmax = df.quantile(clip_quantiles[1]).max().max()

    styled = styled.background_gradient(cmap=cmap, vmin=vmin, vmax=vmax)

    styled = (
        styled
        .set_caption(title)
        .set_table_styles([
            {"selector": "caption", "props": [("caption-side", "top"), ("font-size", "16px"), ("font-weight", "bold"), ("text-align", "center"), ("color", "#333")]},
            {"selector": "th", "props": [("text-align", "center"), ("background-color", "#f8f8f8"), ("font-weight", "bold"), ("border", "1px solid #aaa")]},
            {"selector": "td", "props": [("text-align", "center"), ("padding", "6px 10px"), ("border", "1px solid #ddd")]},
            {"selector": "table", "props": [("border-collapse", "collapse"), ("margin", "10px auto"), ("border", "1px solid #999")]},
        ])
        .set_properties(**{
            "text-align": "center",
            "font-size": "13px"
        })
    )
    return styled


display(style_table(solution_Q_table, "Solution Quality (Deviation from Optimum, %)", cmap='RdYlGn_r'))
# Out:
# <style type="text/css">
# #T_f8198 caption {
#   caption-side: top;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: center;
#   color: #333;
# }
# #T_f8198 th {
#   text-align: center;
#   background-color: #f8f8f8;
#   font-weight: bold;
#   border: 1px solid #aaa;
# }
# #T_f8198 td {
#   text-align: center;
#   padding: 6px 10px;
#   border: 1px solid #ddd;
# }
# #T_f8198 table {
#   border-collapse: collapse;
#   margin: 10px auto;
#   border: 1px solid #999;
# }
# #T_f8198_row0_col0 {
#   background-color: #daf08d;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row0_col1 {
#   background-color: #87cb67;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row0_col2 {
#   background-color: #fed683;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row0_col3 {
#   background-color: #bde379;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row0_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row0_col5 {
#   background-color: #fee797;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row0_col6 {
#   background-color: #ecf7a6;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row0_col7 {
#   background-color: #2aa054;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row0_col8 {
#   background-color: #fdbd6d;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row1_col0, #T_f8198_row4_col3 {
#   background-color: #fff1a8;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row1_col1 {
#   background-color: #a5d86a;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row1_col2 {
#   background-color: #e54e35;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row1_col3 {
#   background-color: #f1f9ac;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row1_col4 {
#   background-color: #b3df72;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row1_col5 {
#   background-color: #fdc776;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row1_col6 {
#   background-color: #fee999;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row1_col7 {
#   background-color: #9bd469;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row1_col8 {
#   background-color: #fa9b58;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row2_col0 {
#   background-color: #f4fab0;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row2_col1 {
#   background-color: #45ad5b;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row2_col2 {
#   background-color: #f7814c;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row2_col3 {
#   background-color: #b9e176;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row2_col4 {
#   background-color: #05713c;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row2_col5 {
#   background-color: #fffbb8;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row2_col6 {
#   background-color: #fdfebc;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row2_col7 {
#   background-color: #91d068;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row2_col8 {
#   background-color: #fca85e;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row3_col0 {
#   background-color: #fb9d59;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row3_col1 {
#   background-color: #e9f6a1;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row3_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row3_col3 {
#   background-color: #fff2aa;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row3_col4 {
#   background-color: #a2d76a;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row3_col5 {
#   background-color: #fdaf62;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row3_col6 {
#   background-color: #fff0a6;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row3_col7 {
#   background-color: #c3e67d;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row3_col8 {
#   background-color: #fdbf6f;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row4_col0 {
#   background-color: #fdb768;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row4_col1 {
#   background-color: #fff5ae;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row4_col2 {
#   background-color: #dd3d2d;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row4_col4 {
#   background-color: #e5f49b;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row4_col5, #T_f8198_row5_col8 {
#   background-color: #f26841;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row4_col6 {
#   background-color: #fee08b;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row4_col7 {
#   background-color: #d5ed88;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row4_col8 {
#   background-color: #ef633f;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row5_col0 {
#   background-color: #fdb365;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row5_col1 {
#   background-color: #fff3ac;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row5_col2 {
#   background-color: #d02927;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row5_col3 {
#   background-color: #fede89;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row5_col4 {
#   background-color: #d7ee8a;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row5_col5 {
#   background-color: #e75337;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row5_col6 {
#   background-color: #fdb567;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_f8198_row5_col7 {
#   background-color: #fff8b4;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# </style>
# <table id="T_f8198">
#   <caption>Solution Quality (Deviation from Optimum, %)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Param set</th>
#       <th id="T_f8198_level0_col0" class="col_heading level0 col0" colspan="3">balanced</th>
#       <th id="T_f8198_level0_col3" class="col_heading level0 col3" colspan="3">exploration</th>
#       <th id="T_f8198_level0_col6" class="col_heading level0 col6" colspan="3">exploitation</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Metric</th>
#       <th id="T_f8198_level1_col0" class="col_heading level1 col0" >Avg.</th>
#       <th id="T_f8198_level1_col1" class="col_heading level1 col1" >Best</th>
#       <th id="T_f8198_level1_col2" class="col_heading level1 col2" >Worst</th>
#       <th id="T_f8198_level1_col3" class="col_heading level1 col3" >Avg.</th>
#       <th id="T_f8198_level1_col4" class="col_heading level1 col4" >Best</th>
#       <th id="T_f8198_level1_col5" class="col_heading level1 col5" >Worst</th>
#       <th id="T_f8198_level1_col6" class="col_heading level1 col6" >Avg.</th>
#       <th id="T_f8198_level1_col7" class="col_heading level1 col7" >Best</th>
#       <th id="T_f8198_level1_col8" class="col_heading level1 col8" >Worst</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Instance</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8198_level0_row0" cl

# %%
# boxplot - deviation distribution for all instances
plt.figure(figsize=(8,5))

sns.boxplot(
    data=multi_df,
    x="Parameter_Set",
    y="Deviation_%",
    hue="Instance",
    palette=instance_colors,
    order=param_order
)

plt.title("Deviation Distribution Across Runs", fontsize=14, weight="bold")
plt.ylabel("Deviation (%)", fontsize=12)
plt.xlabel("Parameter Set", fontsize=12)
plt.grid(axis="y", linestyle="--", alpha=0.5)
plt.legend(title="Instance", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
order = ['small_1', 'small_2', 'medium_1', 'medium_2', 'large_1', 'large_2']

def heatplot_metric(df, col, title, cmap, order, cbar_label, reverse=False):
    # Pivot and fix both axis orders
    p = (
        df.pivot_table(index="Instance", columns="Parameter_Set", values=col, aggfunc="mean")
        .reindex(order)                               # y-axis order
        .reindex(columns=param_order)                 # x-axis order
    )
    vmin, vmax = np.nanmin(p), np.nanmax(p)
    print(f"{title}: vmin={vmin:.2f}, vmax={vmax:.2f}")
    plt.figure(figsize=(7,4))
    sns.heatmap(p, annot=True, fmt=".2f", cmap=cmap + ("_r" if reverse else ""),
                vmin=vmin, vmax=vmax, linewidths=0.5, cbar_kws={'label': cbar_label})
    plt.title(title)
    plt.tight_layout()
    plt.show()

heatplot_metric(multi_df, "Improvement",
            "Improvement (%) from first iteration best to last iteration best",
            "RdYlGn", order, "Improvement (%)")

heatplot_metric(multi_df, "Deviation_%",
            "Deviation (%) from known optimum value",
            "RdYlGn_r", order, "Deviation (%)")
# Out:
# Improvement (%) from first iteration best to last iteration best: vmin=5.55, vmax=8.31
# Deviation (%) from known optimum value: vmin=2.29, vmax=3.95

# %% [markdown]
# #### <span id="section-convergence"></span>Convergence

# %%
def plot_convergence_by_param(multi_df, instance):
    plt.figure(figsize=(7,4))
    for param in multi_df["Parameter_Set"].unique():
        sub = multi_df[(multi_df.Instance==instance) & (multi_df.Parameter_Set==param)]
        if sub.empty:
            continue
        maxL = max(len(h) for h in sub["Hist_Best"])
        H = np.array([h + [h[-1]]*(maxL-len(h)) for h in sub["Hist_Best"]])
        mean, std = H.mean(axis=0), H.std(axis=0)
        x = np.arange(len(mean))
        plt.plot(x, mean, label=param, color=param_colors[param])

    plt.title(f"Convergence — {instance}")
    plt.xlabel("Iteration")
    plt.ylabel("Best-so-far value")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()


# example:
for inst in multi_df["Instance"].unique():
    plot_convergence_by_param(multi_df, inst)

# %%
def plot_all_convergences(multi_df):

    fig, axes = plt.subplots(2, 3, figsize=(14, 8), sharex=True, sharey=False)
    axes = axes.flatten()  # flatten for easy iteration

    for ax, instance in zip(axes, instances):
        for param in param_order:
            sub = multi_df[(multi_df.Instance == instance) & (multi_df.Parameter_Set == param)]
            if sub.empty:
                continue

            # Align histories to same length
            maxL = max(len(h) for h in sub["Hist_Best"])
            H = np.array([h + [h[-1]]*(maxL - len(h)) for h in sub["Hist_Best"]])
            mean, std = H.mean(axis=0), H.std(axis=0)
            x = np.arange(len(mean))

            ax.plot(x, mean, label=param, color=param_colors[param], alpha=0.8)

        ax.set_title(instance, fontsize=11, weight="bold")
        ax.grid(True, linestyle="--", alpha=0.5)
        if ax in axes[-3:]:
            ax.set_xlabel("Iteration")
        if ax in axes[::3]:
            ax.set_ylabel("Best-so-far value")

    # unified legend
    handles, labels = ax.get_legend_handles_labels()
    fig.legend(handles, labels, loc="lower center", ncol=3, frameon=False)

    plt.suptitle("Convergence Curves by Instance", fontsize=15, weight="bold")
    plt.tight_layout(rect=[0, 0.05, 1, 0.96])
    plt.show()

# %%
plot_all_convergences(multi_df)

# %%
heatplot_metric(multi_df, "Iter_of_Best",
            "Average iteration where best value was reached",
            "RdYlGn_r", order, "Iter_of_Best")
# Out:
# Average iteration where best value was reached: vmin=29.70, vmax=126.60

# %% [markdown]
# #### <span id="section-runtime"></span>Runtime

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    data=multi_df,
    x='Instance',
    y='Runtime_s',
    hue='Parameter_Set',
    palette=param_colors
)
plt.title('Runtime by Instance and Parameter Set')
plt.xlabel('Instance')
plt.ylabel('Runtime (s)')
plt.xticks(rotation=45)
plt.legend(
    title='Parameter Set',
    loc='upper center',
    ncol=3
)
plt.tight_layout()
plt.show()

# %%
# keep ascending order of instances
order = ['small_1', 'small_2', 'medium_1', 'medium_2', 'large_1', 'large_2']

# solution quality table
runtime_table = (
    results_df
    .pivot_table(index='Instance', columns='Parameter_Set', values=['Runtime_s', 'Runtime_min', 'Runtime_max'])
    .rename_axis(columns=['Metric', 'Param set'])
    .rename(columns={'Runtime_s': 'Avg.', 'Runtime_min': 'Best', 'Runtime_max': 'Worst'})
    .reorder_levels(['Param set', 'Metric'], axis=1)
    .sort_index(axis=1, level=0)
    .reindex(order)
    .reindex(columns=param_order, level='Param set')
)

# stylize table
def style_table(df, title, cmap='YlGnBu', precision=2, clip_quantiles=(0.01, 0.99)):
    styled = df.style.format(f"{{:.{precision}f}}")

    # Compute global vmin/vmax, but clip outliers for balance
    vmin = df.quantile(clip_quantiles[0]).min().min()
    vmax = df.quantile(clip_quantiles[1]).max().max()

    styled = styled.background_gradient(cmap=cmap, vmin=vmin, vmax=vmax)

    styled = (
        styled
        .set_caption(title)
        .set_table_styles([
            {"selector": "caption", "props": [("caption-side", "top"), ("font-size", "16px"), ("font-weight", "bold"), ("text-align", "center"), ("color", "#333")]},
            {"selector": "th", "props": [("text-align", "center"), ("background-color", "#f8f8f8"), ("font-weight", "bold"), ("border", "1px solid #aaa")]},
            {"selector": "td", "props": [("text-align", "center"), ("padding", "6px 10px"), ("border", "1px solid #ddd")]},
            {"selector": "table", "props": [("border-collapse", "collapse"), ("margin", "10px auto"), ("border", "1px solid #999")]},
        ])
        .set_properties(**{
            "text-align": "center",
            "font-size": "13px"
        })
    )
    return styled


display(style_table(runtime_table, "Runtime (s)", cmap='RdYlGn_r'))
# Out:
# <style type="text/css">
# #T_61f93 caption {
#   caption-side: top;
#   font-size: 16px;
#   font-weight: bold;
#   text-align: center;
#   color: #333;
# }
# #T_61f93 th {
#   text-align: center;
#   background-color: #f8f8f8;
#   font-weight: bold;
#   border: 1px solid #aaa;
# }
# #T_61f93 td {
#   text-align: center;
#   padding: 6px 10px;
#   border: 1px solid #ddd;
# }
# #T_61f93 table {
#   border-collapse: collapse;
#   margin: 10px auto;
#   border: 1px solid #999;
# }
# #T_61f93_row0_col0, #T_61f93_row1_col1 {
#   background-color: #07753e;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row0_col1, #T_61f93_row0_col6 {
#   background-color: #026c39;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row0_col2 {
#   background-color: #18954f;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row0_col3, #T_61f93_row3_col6 {
#   background-color: #097940;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row0_col4, #T_61f93_row2_col0, #T_61f93_row3_col7, #T_61f93_row4_col7 {
#   background-color: #05713c;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row0_col5, #T_61f93_row5_col7 {
#   background-color: #0e8245;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row0_col7, #T_61f93_row2_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row0_col8, #T_61f93_row1_col7 {
#   background-color: #04703b;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row1_col0, #T_61f93_row2_col5, #T_61f93_row3_col4 {
#   background-color: #148e4b;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row1_col2 {
#   background-color: #33a456;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row1_col3 {
#   background-color: #2aa054;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row1_col4 {
#   background-color: #108647;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row1_col5 {
#   background-color: #66bd63;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row1_col6, #T_61f93_row2_col2 {
#   background-color: #08773f;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row1_col8, #T_61f93_row4_col1 {
#   background-color: #0d8044;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row2_col1, #T_61f93_row2_col6 {
#   background-color: #016a38;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row2_col3 {
#   background-color: #0c7f43;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row2_col4 {
#   background-color: #06733d;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row2_col8 {
#   background-color: #036e3a;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row3_col0 {
#   background-color: #138c4a;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row3_col1, #T_61f93_row4_col6 {
#   background-color: #0b7d42;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row3_col2 {
#   background-color: #1b9950;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row3_col3, #T_61f93_row4_col2, #T_61f93_row5_col4 {
#   background-color: #30a356;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row3_col5 {
#   background-color: #82c966;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row3_col8, #T_61f93_row4_col8 {
#   background-color: #118848;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row4_col0 {
#   background-color: #15904c;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row4_col3 {
#   background-color: #42ac5a;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row4_col4 {
#   background-color: #128a49;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row4_col5 {
#   background-color: #98d368;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row5_col0 {
#   background-color: #e3f399;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row5_col1 {
#   background-color: #57b65f;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row5_col2 {
#   background-color: #f36b42;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row5_col3 {
#   background-color: #ebf7a3;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row5_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row5_col6 {
#   background-color: #3ca959;
#   color: #f1f1f1;
#   text-align: center;
#   font-size: 13px;
# }
# #T_61f93_row5_col8 {
#   background-color: #78c565;
#   color: #000000;
#   text-align: center;
#   font-size: 13px;
# }
# </style>
# <table id="T_61f93">
#   <caption>Runtime (s)</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >Param set</th>
#       <th id="T_61f93_level0_col0" class="col_heading level0 col0" colspan="3">balanced</th>
#       <th id="T_61f93_level0_col3" class="col_heading level0 col3" colspan="3">exploration</th>
#       <th id="T_61f93_level0_col6" class="col_heading level0 col6" colspan="3">exploitation</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Metric</th>
#       <th id="T_61f93_level1_col0" class="col_heading level1 col0" >Avg.</th>
#       <th id="T_61f93_level1_col1" class="col_heading level1 col1" >Best</th>
#       <th id="T_61f93_level1_col2" class="col_heading level1 col2" >Worst</th>
#       <th id="T_61f93_level1_col3" class="col_heading level1 col3" >Avg.</th>
#       <th id="T_61f93_level1_col4" class="col_heading level1 col4" >Best</th>
#       <th id="T_61f93_level1_col5" class="col_heading level1 col5" >Worst</th>
#       <th id="T_61f93_level1_col6" class="col_heading level1 col6" >Avg.</th>
#       <th id="T_61f93_level1_col7" class="col_heading level1 col7" >Best</th>
#       <th id="T_61f93_level1_col8" class="col_heading level1 col8" >Worst</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Instance</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61f93_level0_row0" class="row_heading level0 row0" >small_1</th>
#       <td id="T_61f93_row0_col0" class="data row0 col0" >1.44</td>
#       <td id="T_61f93_row0_col1" class="data row0 col1" >0.72</td>
#       <td id="T_61f93_row0_col2" class="data row0 col2" >4.07</td>
#       <td id="T_61f93_row0_col3" class="data row0 col3" >1.75</td>
#       <td id="T_61f93_row0_col4" class="data row0 col4" >1.24</td>
#       <td id="T_61f93_row0_col5" class="data row0 col5" >2.55</td>
#       <td id="T_61f93_row0_col6" class="data row0 col6" >0.70</td>
#       <td id="T_61f93_row0_col7" class="data row0 col7" >0.34</td>
#       <td id="T_61f93_row0_col8" class="data row0 col8" >1.07</td>
#     </tr>
#     <tr>
#       <th id="T_61f93_level0_row1" class="row_heading level0 row1" >small_2</th>
#       <td id="T_61f93_row1_col0" class="data row1 col0" >3.42</td>
#       <td id="T_61f93_row1_col1" class="data row1 col1" >1.42</td>
#       <td id="T_61f93_row1_col2" class="data row1 col2" >5.51</td>
#       <td id="T_61f93_row1_col3" class="data row1 col3" >5.12</td>
#       <td id="T_61f93_row1_col4" class="data row1 col4" >2.87</td>
#       <td id="T_61f93_row1_col5" class="data row1 col5" >8.12</td>
#       <td id="T_61f93_row1_col6" class="data row1 col6" >1.63</td>
#       <td id="T_61f93_row1_col7" class="data row1 col7" >1.07</td>
#       <td id="T_61f93_row1_col8" class="data row1 col8" >2.34</td>
#     </tr>
#     <tr>
#       <th id="T_61f93_level0_row2" class="row_heading level0 row2" >medium_1</th>
#       <td id="T_61f93_row2_col0" class

# %% [markdown]
# #### <span id="section-runtime-performance"></span>Runtime vs. performance

# %%
# find mean runtime and deviation per param set
summary = multi_df.groupby('Parameter_Set', as_index=False).agg({
    'Runtime_s': 'mean',
    'Deviation_%': 'mean'
})

plt.figure(figsize=(9,7))

# scatter of all runs
sns.scatterplot(
    data=multi_df,
    x='Runtime_s',
    y='Deviation_%',
    hue='Parameter_Set',
    palette=param_colors,
    alpha=0.5,         # semi-transparent to show overlap
    s=100,
    edgecolor='none'
)

# add means (star)
sns.scatterplot(
    data=summary,
    x='Runtime_s',
    y='Deviation_%',
    hue='Parameter_Set',
    palette=param_colors,
    s=1300,
    marker='*',
    edgecolor='black',
    legend=False
)

plt.title('Runtime vs Deviation — All runs with means per parameter set')
plt.xlabel('Runtime (s) ↓')
plt.ylabel('Deviation (%) ↓')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Plot convergence for each intstance.
